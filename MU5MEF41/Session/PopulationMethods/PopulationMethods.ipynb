# %% [markdown]
# ## Genetic Algorithms
#
# ### Selection process
#
# ![Selection](fig1.png)
#
# Algorithm corresponding to each selection process:
# ![Algorithm](fig2.png)
#
#
# ### Crossover:
# * Linear interpolation
#
# ### Mutation:
# ![Mutation](fig3.png)
#
#
# ### Final algorithm:
# ![Algorithm](fig4.png)
#
# ### Example:
# ![eg](fig5.png)

# %% [markdown]
# ## Particle Swarm Optimisation
#
# ### Particle Velocity
# ![PV](fig6.png)
#
# ### Algorithm
# ![Algorithm](fig7.png)
#
# ### Example
# ![e,g](fig8.png)
