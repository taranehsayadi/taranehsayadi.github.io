# %% [markdown]
# ## Full Factorial
#
# ![FF](pic1.png)

# %% [markdown]
# Algorithm:
#
# ![Algorithm](pic1a.png)

# %% [markdown]
# ## Uniform projection plan
#
#
# ![pic2](pic2.png)
#
# Algorithm:
# ![Algorithm](pic2a.png)
#
# ### M-element permutation as shown in the figure
#
# ![pic3](pic3.png)
#
# ### Latin square
#
# ![pic4](pic4.png)

# %% [markdown]
# ## Stratified sampling
#
# ![pic5](pic5.png)
# ![pic6](pic6.png)
